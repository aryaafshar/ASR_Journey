# %% [markdown]
# In the name of Allah, the Most Gracious, the Most Merciful

# %%
! pip install hezar

# %%
from hezar.models import Model

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
model = Model.load("hezarai/whisper-small-fa")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_config.yaml:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.pt:   0%|          | 0.00/967M [00:00<?, ?B/s]
# (…)eprocessor/feature_extractor_config.yaml:   0%|          | 0.00/225 [00:00<?, ?B/s]
# preprocessor/tokenizer_config.yaml:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# preprocessor/tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]

# %%
transcripts = model.predict("/content/drive/MyDrive/DML-AI-Audio-Speech/Resources/TestSamples/TestASREasy.m4a")
print(transcripts)
# Out:
# /usr/local/lib/python3.10/dist-packages/hezar/utils/audio_utils.py:34: UserWarning: PySoundFile failed. Trying audioread instead.
#   inputs = [librosa.load(x, sr=sampling_rate)[0] for x in paths]
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [{'text': 'این صوت برای آزمایش مدل تبدیل گفتار به متن است.'}]

# %%
transcripts = model.predict("/content/drive/MyDrive/DML-AI-Audio-Speech/Resources/TestSamples/TestASRNormal.m4a")
print(transcripts)
# Out:
# [{'text': 'این صوت برای آزمایش مدل تبدیل گفتار به متن است.'}]

# %%
transcripts = model.predict("/content/drive/MyDrive/DML-AI-Audio-Speech/Resources/TestSamples/TestASRHard.m4a")
print(transcripts)
# Out:
# /usr/local/lib/python3.10/dist-packages/hezar/utils/audio_utils.py:34: UserWarning: PySoundFile failed. Trying audioread instead.
#   inputs = [librosa.load(x, sr=sampling_rate)[0] for x in paths]
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [{'text': 'این صوت برای آزمایش مدل تبدیل گفتار بمتنه'}]

# %%
transcripts = model.predict("/content/drive/MyDrive/DML-AI-Audio-Speech/Resources/TestSamples/TestASRBeGhasdeKosht.m4a")
print(transcripts)
# Out:
# /usr/local/lib/python3.10/dist-packages/hezar/utils/audio_utils.py:34: UserWarning: PySoundFile failed. Trying audioread instead.
#   inputs = [librosa.load(x, sr=sampling_rate)[0] for x in paths]
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [{'text': 'واقعاً انتظار نداشتم مدل آنقدر خوب عمل کنم.'}]
